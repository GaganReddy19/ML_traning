# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4, 2.56789, 9, 87.9999, 40, 'hyderbad']
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'hyderbad']

# %%
pd.Series(k)
# Out:
# 0           4
# 1     2.56789
# 2           9
# 3     87.9999
# 4          40
# 5    hyderbad
# dtype: object

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([23, 24, 38, 24, 30, 27, 22, 29, 21, 48, 24, 21, 48, 45, 31])

# %%
a.ndim
# Out:
# 1

# %%
pd.Series(a)
# Out:
# 0     23
# 1     24
# 2     38
# 3     24
# 4     30
# 5     27
# 6     22
# 7     29
# 8     21
# 9     48
# 10    24
# 11    21
# 12    48
# 13    45
# 14    31
# dtype: int64

# %%
b=np.random.randint(100,200,(6,5))

# %%
b.ndim
# Out:
# 2

# %%
b
# Out:
# array([[149, 136, 113, 113, 166],
#        [165, 141, 124, 171, 175],
#        [150, 173, 122, 195, 141],
#        [121, 175, 119, 112, 161],
#        [135, 106, 189, 188, 194],
#        [191, 125, 182, 117, 154]])

# %%
b.shape
# Out:
# (6, 5)

# %%
pd.DataFrame(b)
# Out:
#      0    1    2    3    4
# 0  149  136  113  113  166
# 1  165  141  124  171  175
# 2  150  173  122  195  141
# 3  121  175  119  112  161
# 4  135  106  189  188  194
# 5  191  125  182  117  154

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Country','Marks'],index=[200,202,204,205,208,210])
df
# Out:
#      Roll  Name  Age  Country  Marks
# 200   149   136  113      113    166
# 202   165   141  124      171    175
# 204   150   173  122      195    141
# 205   121   175  119      112    161
# 208   135   106  189      188    194
# 210   191   125  182      117    154

# %%
df.loc[204]
# Out:
# Roll       150
# Name       173
# Age        122
# Country    195
# Marks      141
# Name: 204, dtype: int64

# %%
df.iloc[0]
# Out:
# Roll       149
# Name       136
# Age        113
# Country    113
# Marks      166
# Name: 200, dtype: int64

# %%
df.loc[204,'Roll']
# Out:
# 150

# %%
df.iloc[0,0]
# Out:
# 149

# %%
df.loc[204,['Roll','Name','Age']]
# Out:
# Roll    150
# Name    173
# Age     122
# Name: 204, dtype: int64

# %%
df.iloc[0,0:3]
# Out:
# Roll    149
# Name    136
# Age     113
# Name: 200, dtype: int64

# %%
df.iloc[[2,5]]
# Out:
#      Roll  Name  Age  Country  Marks
# 204   150   173  122      195    141
# 210   191   125  182      117    154

# %%
df.iloc[[1,3,4]]
# Out:
#      Roll  Name  Age  Country  Marks
# 202   165   141  124      171    175
# 205   121   175  119      112    161
# 208   135   106  189      188    194

# %%
df.loc[[200,202,204]]
# Out:
#      Roll  Name  Age  Country  Marks
# 200   149   136  113      113    166
# 202   165   141  124      171    175
# 204   150   173  122      195    141

# %%
df['Age']
# Out:
# 200    113
# 202    124
# 204    122
# 205    119
# 208    189
# 210    182
# Name: Age, dtype: int64

# %%
df[['Roll','Marks']]
# Out:
#      Roll  Marks
# 200   149    166
# 202   165    175
# 204   150    141
# 205   121    161
# 208   135    194
# 210   191    154

# %%
df.loc[[200,204,205],['Roll','Marks','Country']]
# Out:
#      Roll  Marks  Country
# 200   149    166      113
# 204   150    141      195
# 205   121    161      112

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('seaice')
# Out:
#             Date  Extent
# 0     1980-01-01  14.200
# 1     1980-01-03  14.302
# 2     1980-01-05  14.414
# 3     1980-01-07  14.518
# 4     1980-01-09  14.594
# ...          ...     ...
# 13170 2019-12-27  12.721
# 13171 2019-12-28  12.712
# 13172 2019-12-29  12.780
# 13173 2019-12-30  12.858
# 13174 2019-12-31  12.889
#
# [13175 rows x 2 columns]

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (6, 5)
